# %%
# Algorithm 1 Implementation

# %%
import pandas as pd
import numpy as np
import timeit 
import matplotlib.pyplot as plt

# %%
def Algo1(words, abb):
    output = []
    for w in words:
        if (w in abb.keys()):
            output.append(abb[w])
        else:
            output.append(w)
    return output

# %%
# Setting Up The Data
tweetdata = pd.read_csv("com.rockstargames.gtasa.csv")
slangdata = pd.read_csv("Slang-dataset/slang.csv")
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16612\3110995534.py:2: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweetdata = pd.read_csv("com.rockstargames.gtasa.csv")

# %%
content = tweetdata['content']
content = content.dropna()
tweetlist = content.tolist()

# %%
words = []
for string in tweetlist:
    x = string.split()
    words.append(x)

# %%
slangdata = slangdata.dropna()
slangdict = {}
slangac = slangdata['acronym']
slangexp = slangdata['expansion']
slangdict = {k : v for k, v in zip(slangac, slangexp)}

# %%
# Test
o = []
for i in words:
    o.append(Algo1(i, slangdict))

# %%
# Plot of Algo1
ns = range(1, 100)
ts = [(2*n + 2) for n in ns]
plt.plot(ns, ts, '-r', label='Algo1 (2n + 2)');

ns = range(1,100)
ts = [(n) for n in ns]
plt.plot(ns, ts, '-b', label='O(n)')
plt.legend(loc='upper left')
plt.show()
